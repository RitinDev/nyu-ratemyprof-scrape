# %%
import json
import pandas as pd

# %%
data = json.load(open('nyu-prof-data.json'))

# Extracting the teacher information
professors = data['data']['search']['teachers']['edges']

df = pd.DataFrame()

for professor in professors:
    node = professor['node']
    full_name = f"{node['firstName']} {node['lastName']}"
    rating = node['avgRating']
    department = node['department']
    difficulty = node['avgDifficulty']
    num_ratings = node['numRatings']
    
    df = pd.concat([df, pd.DataFrame({
        'Name': [full_name],
        'Average Rating': [rating],
        'Department': [department],
        'Difficulty Rating': [difficulty],
        'Number of Ratings': [num_ratings]
    })], ignore_index=True)
    

df
# Out:
#                              Name  Average Rating        Department  \
# 0                    Phillip Kain             4.3           English
# 1                Richard Borowsky             2.6           Biology
# 2                   Meretzky Mark             3.5  Computer Science
# 3                   Susanna Horng             3.3           Writing
# 4                  Robert Diyanni             4.7  Cultural Studies
# ...                           ...             ...               ...
# 4995                Niccolo Rossi             3.0           Italian
# 4996                Tamer Avcilar             2.0       Hospitality
# 4997                   Tim Crouse             4.0   Theatre & Dance
# 4998  Ethiraj Gabriel Dattatreyan             5.0      Anthropology
# 4999             Matthew Korahais             5.0   Theatre & Dance
#
#       Difficulty Rating  Number of Ratings
# 0                   3.6                 19
# 1                   3.5                 12
# 2                   2.7                  3
# 3                   3.5                 56
# 4                   2.3                 39
# ...                 ...                ...
# 4995                4.0                  1
# 4996                3.0                  1
# 4997                4.0                  1
# 4998                1.8                  3
# 4999                2.9                  5
#
# [5000 rows x 5 columns]

# %%
# Keep only rows with unique (name, department) pairs
df = df.drop_duplicates(subset=['Name', 'Department'], keep='first')

df
# Out:
#                              Name  Average Rating        Department  \
# 0                    Phillip Kain             4.3           English
# 1                Richard Borowsky             2.6           Biology
# 2                   Meretzky Mark             3.5  Computer Science
# 3                   Susanna Horng             3.3           Writing
# 4                  Robert Diyanni             4.7  Cultural Studies
# ...                           ...             ...               ...
# 4995                Niccolo Rossi             3.0           Italian
# 4996                Tamer Avcilar             2.0       Hospitality
# 4997                   Tim Crouse             4.0   Theatre & Dance
# 4998  Ethiraj Gabriel Dattatreyan             5.0      Anthropology
# 4999             Matthew Korahais             5.0   Theatre & Dance
#
#       Difficulty Rating  Number of Ratings
# 0                   3.6                 19
# 1                   3.5                 12
# 2                   2.7                  3
# 3                   3.5                 56
# 4                   2.3                 39
# ...                 ...                ...
# 4995                4.0                  1
# 4996                3.0                  1
# 4997                4.0                  1
# 4998                1.8                  3
# 4999                2.9                  5
#
# [5000 rows x 5 columns]

# %%
# Remove rows with Number of Ratings of 0
df = df[df['Number of Ratings'] != 0]

df
# Out:
#                              Name  Average Rating        Department  \
# 0                    Phillip Kain             4.3           English
# 1                Richard Borowsky             2.6           Biology
# 2                   Meretzky Mark             3.5  Computer Science
# 3                   Susanna Horng             3.3           Writing
# 4                  Robert Diyanni             4.7  Cultural Studies
# ...                           ...             ...               ...
# 4995                Niccolo Rossi             3.0           Italian
# 4996                Tamer Avcilar             2.0       Hospitality
# 4997                   Tim Crouse             4.0   Theatre & Dance
# 4998  Ethiraj Gabriel Dattatreyan             5.0      Anthropology
# 4999             Matthew Korahais             5.0   Theatre & Dance
#
#       Difficulty Rating  Number of Ratings
# 0                   3.6                 19
# 1                   3.5                 12
# 2                   2.7                  3
# 3                   3.5                 56
# 4                   2.3                 39
# ...                 ...                ...
# 4995                4.0                  1
# 4996                3.0                  1
# 4997                4.0                  1
# 4998                1.8                  3
# 4999                2.9                  5
#
# [3928 rows x 5 columns]

# %%
# Get mean rating for each department
mean_ratings = df.groupby('Department')['Average Rating'].mean().reset_index()
mean_ratings = mean_ratings.sort_values(by='Average Rating', ascending=False)

mean_ratings
# Out:
#                          Department  Average Rating
# 20                Arts amp Sciences        5.000000
# 124           Publishing & Printing        5.000000
# 79   Interactive Telecommunications        5.000000
# 64                         Genetics        5.000000
# 1                    Administration        5.000000
# ..                              ...             ...
# 137               Sports Management        2.700000
# 27                     Business Law        2.500000
# 120           Professional Programs        2.333333
# 140              Teaching  Learning        2.000000
# 67            Health Administration        1.200000
#
# [151 rows x 2 columns]

# %%
# Get mean difficulty rating for each department
mean_difficulty = df.groupby('Department')['Difficulty Rating'].mean().reset_index()
mean_difficulty = mean_difficulty.sort_values(by='Difficulty Rating', ascending=False)

mean_difficulty
# Out:
#                               Department  Difficulty Rating
# 140                   Teaching  Learning           4.500000
# 9                           Architecture           4.500000
# 59   Foundations of Am. Culture/Classics           4.300000
# 122                Public Administration           4.075000
# 22                          Biochemistry           4.066667
# ..                                   ...                ...
# 46          English As A Second Language           2.000000
# 141                  Teaching & Learning           1.937500
# 3                        African Studies           1.833333
# 142                Teaching amp Learning           1.700000
# 64                              Genetics           1.000000
#
# [151 rows x 2 columns]

# %%
# Get number of ratings for each department
num_ratings = df.groupby('Department')['Number of Ratings'].sum().reset_index()
num_ratings = num_ratings.sort_values(by='Number of Ratings', ascending=False)

num_ratings
# Out:
#                 Department  Number of Ratings
# 150                Writing               4198
# 98             Mathematics               2399
# 41               Economics               1872
# 45                 English               1682
# 121             Psychology               1663
# ..                     ...                ...
# 26      Business Economics                  1
# 1           Administration                  1
# 124  Publishing & Printing                  1
# 20       Arts amp Sciences                  1
# 64                Genetics                  1
#
# [151 rows x 2 columns]

# %%
# Create a matrix of the mean ratings, mean difficulty ratings, and number of ratings for each department
department_stats = mean_ratings.merge(mean_difficulty, on='Department')
department_stats = department_stats.merge(num_ratings, on='Department')

# Replace ' amp ' with ' & ' in the Department column
department_stats['Department'] = department_stats['Department'].str.replace(' amp ', ' & ')

department_stats
# Out:
#                          Department  Average Rating  Difficulty Rating  \
# 0                   Arts & Sciences        5.000000                3.0
# 1             Publishing & Printing        5.000000                4.0
# 2    Interactive Telecommunications        5.000000                4.0
# 3                          Genetics        5.000000                1.0
# 4                    Administration        5.000000                3.0
# ..                              ...             ...                ...
# 146               Sports Management        2.700000                4.0
# 147                    Business Law        2.500000                2.7
# 148           Professional Programs        2.333333                3.3
# 149              Teaching  Learning        2.000000                4.5
# 150           Health Administration        1.200000                3.0
#
#      Number of Ratings
# 0                    1
# 1                    1
# 2                    2
# 3                    1
# 4                    1
# ..                 ...
# 146                 14
# 147                  7
# 148                 24
# 149                  6
# 150                  3
#
# [151 rows x 4 columns]

# %%
# Get departments with 50 or more ratings
department_stats = department_stats[department_stats['Number of Ratings'] >= 50]

department_stats
# Out:
#                               Department  Average Rating  Difficulty Rating  \
# 9                    Independent Studies        4.800000           3.400000
# 10                      Natural Sciences        4.800000           2.100000
# 20                     Foreign Languages        4.494737           2.752632
# 24             Interdisciplinary Studies        4.373684           3.110526
# 26                                German        4.300000           2.906250
# ..                                   ...             ...                ...
# 131                           Management        3.185714           3.161905
# 133                         Data Science        3.113333           3.546667
# 135                          Hospitality        3.030000           2.900000
# 140  Foundations of Am. Culture/Classics        2.900000           4.300000
# 143              International Relations        2.781818           3.327273
#
#      Number of Ratings
# 9                  108
# 10                  80
# 20                  62
# 24                  74
# 26                  57
# ..                 ...
# 131                 81
# 133                102
# 135                100
# 140                168
# 143                 70
#
# [80 rows x 4 columns]
